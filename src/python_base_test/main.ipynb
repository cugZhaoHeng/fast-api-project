# %% [markdown]
# 测试Python中字符串的几种写法，如f-string, 三引号的用法

# %%
s1 = """ABC"""
print(f"s1={s1}")
s1='''hello
I am "zhangsan".
'''
print(f"s1={s1}")

n1 = 0.12345
print(f"n1={n1:.2f}")
# Out:
# s1=ABC
# s1=hello
# I am "zhangsan".
#
# n1=0.12

# %% [markdown]
# 测试python代码中，dict和类之间的相互转换，使用**

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def __str__(self):
        return f"Person(name={self.name}, age={self.age})"

person = Person(**{
    "name": "zhangsan",
    "age": 22
})
print(f"person={person}")
# Out:
# person=Person(name=zhangsan, age=22)

# %% [markdown]
# 测试python中函数返回元组，然后用两个变量接收

# %%
def get_name_and_age() -> tuple[str, int]:
    return "lisi", 30

name, age = get_name_and_age()
print(f"name={name}, age={age}")
# Out:
# name=lisi, age=30

# %% [markdown]
# 测试python中列表的extend函数

# %%
a1 = [1,2,3]
b1 = [4,5,6]
a1.extend(b1)
print(f"a1={a1}")
# Out:
# a1=[1, 2, 3, 4, 5, 6]
